# %% [markdown]
# <a href="https://colab.research.google.com/github/cotieno707/ITAI_ML_FirstRepo_Collins_Otieno/blob/main/My_first_code_cell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Your first computer vision code
print ("Hello, Computer Vision World!")

#check if we're in Colab
import sys
if 'google.colab' in sys.modules:
  print ("checkmark You're running in Google Colab!")
else:
  print ("crossmark This doesn't appear to be Colab!")
# Out:
# Hello, Computer Vision World!
# checkmark You're running in Google Colab!
